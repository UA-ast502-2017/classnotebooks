# %%
# %pylab inline --no-import-all
plt.style.use('ggplot')
matplotlib.rc('image', origin='lower', cmap='magma')
matplotlib.rc('axes', grid=False)
from astropy.io import fits
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # What's in one of these headers, anyway?

# %%
fits.getheader('./data/laplace/dd1/contemp_flats_repaired/n47f04p8q_clc_calf.fits')
# Out:
# SIMPLE  =                    T /image conforms to FITS standard
# BITPIX  =                    8 /bits per data value
# NAXIS   =                    0 /number of axes
# EXTEND  =                    T /file may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# IRAF-TLM= '13:19:18 (26/06/2009)' / Time of last modification
# NEXTEND =                    5 / Number of standard extensions
# DATE    = '2009-06-26T19:19:18' / date this file was written (yyyy-mm-dd)
# FILENAME= 'n47f04p8q_clc_cal.fits' / name of file
# FILETYPE= 'SCI      '          / type of data found in data file
#
# TELESCOP= 'HST'                / telescope used to acquire data
# INSTRUME= 'NICMOS'             / identifier for instrument used to acquire data
# EQUINOX =               2000.0 / equinox of celestial coord. system
#
#               / DATA DESCRIPTION KEYWORDS
#
# ROOTNAME= 'n47f04p8q                         ' / rootname of the observation set
# IMAGETYP= 'EXT               ' / type of exposure identifier
# PRIMESI = 'NICMOS'             / instrument designated as prime
#
#               / TARGET INFORMATION
#
# TARGNAME= 'V892-TAU                      ' / proposer's target name
# RA_TARG =   6.466950000000E+01 / right ascension of the target (deg) (J2000)
# DEC_TARG=   2.832111111111E+01 / declination of the target (deg) (J2000)
# ECL_LONG=            67.708891 / ecliptic longitude of the target (deg) (J2000)
# ECL_LAT =             6.820968 / ecliptic latitude of the target (deg) (J2000)
# GAL_LONG=           168.835646 / galactic longitude of the target (deg) (J2000)
# GAL_LAT =           -15.549180 / galactic latitude of the target (deg) (J2000)
#
#               / OTHER COORDINATE SYSTEM INFORMATION
#
# APER_REF= 'NIC2COR   '         / aperture used for reference position
# ELON_REF=            67.708893 / ecliptic longitude at reference position (deg)
# ELAT_REF=             6.820966 / ecliptic latitude at reference position (deg)
# GLON_REF=           168.835649 / galactic longitude at reference position (deg)
# GLAT_REF=           -15.549180 / galactic latitude at reference position (deg)
#
#               / PROPOSAL INFORMATION
#
# PROPOSID=                 7418 / PEP proposal identifier
# LINENUM = '4.044          '    / proposal logsheet line number
# PR_INV_L= 'Padgett                       ' / last name of principal investigator
# PR_INV_F= 'Deborah             ' / first name of principal investigator
# PR_INV_M= '                    ' / middle name / initial of principal investigat
#
#               / EXPOSURE INFORMATION
#
# ORIENTAT=             -160.493 / position angle of image y axis (deg. e of n)
# SUNANGLE=            97.581039 / angle between sun and V1 axis
# MOONANGL=           160.690140 / angle between moon and V1 axis
# SUN_ALT =            75.574226 / altitude of the sun above Earth's limb
# FGSLOCK = 'FINE/GYRO         ' / commanded FGS lock (FINE,COARSE,GYROS,UNKNOWN)
# GYROMODE= '3'                  / observation scheduled with only two gyros (Y/N)
# REFFRAME= 'GSC1    '           / guide star catalog version
#
# DATE-OBS= '1998-02-18'         / UT date of start of observation (yyyy-mm-dd)
# TIME-OBS= '23:21:43'           / UT time of start of observation (hh:mm:ss)
# EXPSTART=   5.086297342143E+04 / exposure start time (Modified Julian Date)
# EXPEND  =   5.086297934736E+04 / exposure end time (Modified Julian Date)
# EXPTIME =             511.9538 / exposure duration (seconds)--calculated
# EXPFLAG = 'NORMAL       '      / Exposure interruption indicator
# QUALCOM1= 'NO APPARENT PROBLEMS                                                '
# QUALCOM2= '                                                                    '
# QUALCOM3= '                                                                    '
# QUALITY = 'OK                                                                  '
#
#               / INSTRUMENT CONFIGURATION INFORMATION
#
# CAMERA  =                    2 / Camera in use (1, 2, or 3)
# PRIMECAM=                    2 / Primary camera for internal parallels
# FOCUS   = 'CORON     '         / In-focus camera for this observation
# APERTURE= 'NIC2-CORON'         / aperture in use (NICi,NICi-FIX,NIC2-CORON/ACQ)
# OBSMODE = 'MULTIACCUM'         / array readout mode (ACCUM, MULTIACCUM, etc.)
# FILTER  = 'F110W  '            / filter wheel element in beam during observation
# NUMITER =                    1 / number of exposure iterations
# NREAD   =                    1 / ACCUM - number of initial and final readouts
# NSAMP   =                   13 / RAMP, MULTI-ACCUM - number of samples
# SAMP_SEQ= 'STEP256 '           / MultiAccum exposure time sequence name
# CR_ELIM = 'NoCR    '           / RAMP - onboard cosmic ray detection used
# SAT_ELIM= 'YES     '           / RAMP - on-board saturation detection used
# CRTHRESH=                  0.0 / RAMP - on-board cosmic ray detect threshold
# SATHRESH=                  0.0 / RAMP - on-board saturation threshold
# VARSCALE=                  0.0 / RAMP - on-board scale factor for variance
# FOMXPOS =                  0.0 / X offset of FOV using NICMOS FOM (arcsec)
# FOMYPOS =                  0.0 / Y offset of FOV using NICMOS FOM (arcsec)
# NFXTILTP=            0.0085182 / Fom X TILT Position (arcsec)
# NFYTILTP=           0.00442497 / Fom Y TILT Position (arcsec)
# NPXTILTP=               2817.0 / PAM X TILT Position (steps)
# NPYTILTP=               2853.0 / PAM Y TILT Position (steps)
# NPFOCUSP=              3.34332 / Pam FOCUS Position (mm)
# TIMEPATT=                   12 / timing pattern id
# READOUT = 'FAST'               / detector array readout rate (FAST, SLOW)
# SAMPZERO=             0.203000 / sample time of the zeroth read (sec)
# HCLKRATE=                10.49 / horizontal clock rate (microseconds)
# VIDEO_BW=                400.0 / readout video bandwidth (kHz)
# ADCGAIN =                  5.4 / analog-digital conversion gain (electrons/DN)
#
#               / BACKGROUND KEYWORDS
#
# BACKEST1=                  0.0 / background estimate number 1
# BACKEST2=             0.000000 / background estimate number 2
# BACKEST3=             0.000000 / background estimate number 3
#
#               / PHOTOMETRY KEYWORDS
#
# PHOTMODE= 'NICMOS,2,F110W,DN'  /
# PHOTFLAM=        4.3487801E-19 / inverse sensitivity (ergs/cm**2/Angstrom/DN)
# PHOTFNU =        1.8472400E-06 / inverse sensitivity (JY*sec/DN)
# PHOTZPT =       -2.1100000E+01 / ST magnitude system zero point (mag)
# PHOTPLAM=        1.1284700E+04 / pivot wavelength of the photmode (Angstroms)
# PHOTBW  =        1.6324000E+03 / RMS bandwidth of the photmode (Angstroms)
#
#               / POST-SAA DARK KEYWORDS
#
# SAA_EXIT= '                 '  / time of last exit from SAA contour level 23
# SAA_TIME=                    0 / seconds since last exit from SAA contour 23
# SAA_DARK= 'N/A      '          / association name for post-SAA dark exposures
# SAACRMAP= 'N/A               ' / SAA cosmic ray map file
#
# SAADFILE= 'N/A                    ' / SAA dark reference image file
# SAADPDGR= 'N/A                                     ' / SAA dark ref file pedigre
#               / CALNICA CALIBRATION REFERENCE FILES
#
# MASKFILE= 'nref$cyc7_msk.fits ' / static data quality file
# NOISFILE= 'nref$h4216218n_noi.fits' / detector read noise file
# NLINFILE= 'nref$l1i1225en_lin.fits' / detector nonlinearities file
# DARKFILE= 'dref$n47f04p8q_dark.fits' / dark current file
# TEMPFILE= 'nref$m3b1331hn_tdd.fits' / temperature-dependent dark file
# FLATFILE= 'fref$n47f04p8q_flh.fits' / flat field file
# PHOTTAB = 'nref$qbk17011n_pht.fits' / photometric calibration table
# BACKTAB = 'N/A                    ' / background model parameters table
#
# IDCTAB  = 'N/A                    ' / Image Distortion Correction table
#               / CALNICA CALIBRATION REFERENCE FILE PEDIGREE
#
# MASKPDGR= 'INFLIGHT'           / static data quality file
# NOISPDGR= 'GROUND 27/01/1997'  / detector read noise file
# NLINPDGR= 'INFLIGHT 05/08/1999' / detector nonlinearities f
# DARKPDGR= 'MODEL 18/02/2002'   / dark current file pedigre
# FLATPDGR= 'GROUND  '           / flat field file pedigree
# PHOTPDGR= 'INFLIGHT 05/08/1997 - 07/08/1997' / photometric calibration t
# BACKPDGR= '                                        ' / background model paramete
#
#               / CALNICA CALIBRATION SWITCHES: perform,omit
#
# BIASCORR= 'PERFORM '           / subtract ADC bias level
# ZSIGCORR= 'PERFORM '           / Zero read signal correction
# ZOFFCORR= 'PERFORM '           / subtract MULTIACCUM zero read
# MASKCORR= 'PERFORM '           / data quality initialization
# NOISCALC= 'PERFORM '           / calculate statistic errors
# NLINCORR= 'PERFORM '           / correct for detector nonlinearities
# DARKCORR= 'PERFORM '           / dark correction
# BARSCORR= 'PERFORM '           / bars correction
# FLATCORR= 'PERFORM '           / flat field correction
# UNITCORR= 'PERFORM '           / convert to count rates
# PHOTCALC= 'PERFORM '           / calculate photometric keywords
# CRIDCALC= 'PERFORM '           / identify cosmic ray hits
# BACKCALC= 'PERFORM '           / calculate background estimates
# WARNCALC= 'PERFORM '           / generate user warnings
#
#               / CALNICA CALIBRATION INDICATORS: performed, skipped, omitted
#
# BIASDONE= 'PERFORMED'          / subtract ADC bias level
# ZSIGDONE= 'PERFORMED'          / Zero read signal correction
# ZOFFDONE= 'PERFORMED'          / subtract MULTI-ACCUM zero read
# MASKDONE= 'PERFORMED'          / data quality initialization
# NOISDONE= 'PERFORMED'          / calculate statistic errors
# NLINDONE= 'PERFORMED'          / correct for detector nonlinearities
# DARKDONE= 'PERFORMED'          / dark correction
# BARSDONE= 'PERFORMED'          / bars correction
# FLATDONE= 'PERFORMED'          / flat field correction
# UNITDONE= 'PERFORMED'          / convert to count rates
# PHOTDONE= 'PERFORMED'          / calculate photometric keywords
# CRIDDONE= 'PERFORMED'          / identify cosmic ray hits
# BACKDONE= '         '          / calculate background estimates
# WARNDONE= '         '          / generate user warnings
#
# CALSTAGE= 'CALNICA '           / state of calibration
# CAL_VER = 'Version 4.1.1'      / CALNIC code version
# PROCTIME=   5.436948225694E+04 / Pipeline processing time (MJD)
# OPUS_VER= 'OPUS 2006_6a      ' / OPUS software system version number
#
#               / POINTING INFORMATION
#
# PA_V3   =           245.023605 / position angle of V3-axis of HST (deg)
#
#               / CALNICB CALIBRATION INFORMATION
#
# ILLMCORR= 'PERFORM '           / background illumination pattern subtraction
# ILLMDONE= '         '          / background illumination pattern subtraction
# ILLMFILE= 'nref$h241323pn_ilm.fits' / background illumination pattern file name
# ILLMPDGR= '                                        ' / background illumination p
# MEAN_BKG=             0.000000 / mean background level (DN/sec)
#
#               / OTFR KEYWORDS
#
# T_SGSTAR= 'F                 ' / OMS calculated guide star control
#
#               / PATTERN KEYWORDS
#
# PATTERN1= 'NONE                    ' / primary pattern type
# P1_SHAPE= 'LINE              ' / primary pattern shape
# P1_PURPS= 'MOSAIC    '         / primary pattern purpose
# P1_NPTS =                    0 / number of points in primary pattern
# P1_PSPAC=             0.000000 / point spacing for primary pattern (arc-sec)
# P1_LSPAC=             0.000000 / line spacing for primary pattern (arc-sec)
# P1_ANGLE=             0.000000 / angle between sides of parallelogram patt (deg)
# P1_FRAME= 'CELESTIAL'          / coordinate frame of primary pattern
# P1_ORINT=             0.000000 / orientation of pattern to coordinate frame (deg
# P1_CENTR= 'NO '                / center pattern relative to pointing (yes/no)
# BKG_OFF = 'SAM'                / pattern offset method (SAM or FOM)
# PATTSTEP=                    0 / position number of this point in the pattern
# PATTERN = 'NONE              ' / pattern type
#
#               / Target Acquisition Keywords
#
# NCHKBOXX=                  136 / CHecKBOX location X
# NCHKBOXY=                   93 / CHecKBOX location Y
# NTABOXSZ=                    3 / TA checkBOX SiZe
# NXCENT  =                35073 / X pos CENTroid (steps)
# NYCENT  =                24307 / Y pos CENTroid (steps)
# NXCENTP =              137.004 / X pos CENTroid (pixels)
# NYCENTP =              94.9492 / Y pos CENTroid (pixels)
# NBOXSUM =                 1082 / checkBoX  SUM
# NOFFSETX=                11950 / OFFSET maneuver X (steps)
# NOFFSETY=                54085 / OFFSET maneuver Y (steps)
# NOFFSTXP=              93.3586 / OFFSeT maneuver X (pixels)
# NOFFSTYP=             -89.4609 / OFFSeT maneuver Y (pixels)
# NSLEWCON= 'Clear'              / SLEW CONfirmation (Clear,Set)
#
#               / ASSOCIATION KEYWORDS
#
# ASN_ID  = 'NONE      '         / unique identifier assigned to association
# ASN_TAB = '                       ' / name of the association table
# ASN_MTYP= '            '       / Role of the Member in the Association
# TARSIAFX=              71.5899 /Target SIAF X location (pixels)
# TARSIAFY=              212.355 /Target SIAF Y location (pixels)
# J_2MASS =              8.74200 /target J band magnitude (2MASS catalog)
# JE_2MASS=      0.0270000000000 /2MASS J magnitude uncertainity
# H_2MASS =              7.01600 /target H band magnitude (2MASS catalog)
# HE_2MASS=      0.0290000000000 /2MASS H magnitude uncertainity
# K_2MASS =              5.78700 /target Ks band magnitude (2MASS catalog)
# KE_2MASS=      0.0160000000000 /2MASS Ks magnitude uncertainity
# F110W_EF= 'N       '           /K band SED flux density Excess Flag (Y,N)
# F110W_JY=       0.443175000000 /filterband target flux density estimate (JY)
# CPHOTSTR= 'rn(icat(k93models,2000,0.0,5.38),band(j),8.742,vegamag)' /band transf
# F110W_FF= 'N       '           /
#
#
# HISTORY Bad pixels modified by IDL routine, lbadpixels.pro
# RADIUS  =              3.00000 /Interpolation radius
# FWHM    =              1.51250 /Interpolation FWHM
# TARGTYPE= 'POINT_SOURCE'       /
# TARGCNTR= 'CENTERED'           /
# PSFQUAL = 'OK            '     /
# PSFCRSAT= 'NO         '        /
# PSFDEGRD= 'NO         '        /

# %% [markdown]
# Columns it might make sense to have:
#
#   - `ORIENTAT` - position angle of image y axis (deg. e of n)
#   - `APERTURE` - aperture in use (NICi,NICi-FIX,NIC2-CORON/ACQ)
#   - `FILTER` - filter used
#   - `PA_V3` - position angle of V3-axis of HST (deg)
#   - `TARGTYPE`
#     - `POINT_SOURCE` - Unresolved, Isolated, Point Source (Star)
#     - `EXTENDED_SOURCE` - Spatially Resolved Bright Source (e.g., circumstellar disk)
#     - `DOUBLE_STAR` - Double Star With Well Separated Components
#     - `CORON_DOUBLE` - ≤ 0.3" overlapping PSF cores inside coronagraph
#     - `FAINT_OBJ` - Spatially Resolved Faint Source (e.g., QSO, AGN)
#     - `NONE` - No Target or PSF Wings/Halo Appear in the Image
#     - `FAILED` - Failed Observation (degraded or useless data)
#   - `TARGCNTR`
#     - `CENTERED` - Target Nominally Positioned in Coronagraph
#     - `DECENTERED` - Target in Coronagraph But Decentered
#     - `PERIPHERY` - Target at the Periphery of the Coronagraphic Mask
#     - `UNOCCULTED` - Target in FOV but Not Coronagraphically Occulted
#     - `UNSTABLE` - Target drifting in aperture
#     - `OUTFOV` - Target Out of FOV but PSF Wings (Halo) Seen in FOV
#     - `NOTARGET` - No Obvious Target Appears in the Image
#   - `PSFQUAL`
#     - `OK` - PSF Quality OK for POINT SOURCE Template Subtraction / Image/PSF Quality OK for Science Targets of Interest
#     - `BAD` - Target Visible but Pointing Unstable (drifting, etc.)
#   - `PSFCRSAT` - `YES` or `NO` - PSF Core Saturated (even just 1 pixel, wings may be OK)
#   - `PSFDEGRD` - `YES` or `NO` - PSF Optically Degraded (focus, image smear, other issues)

# %% [markdown]
# Take inspiration from ALICE to choose where to concentrate our efforts...
#
# > The PSF libraries assembled by the ALICE pipeline are thus much larger in the F110W and F160W filters than in the other filters. Furthermore, as ALICE’s reprocessing is based on Multi-Reference star Differential Imaging (MRDI) and excludes images with detected circumstellar material from the reference PSF libraries (except in “planet mode”, which includes images of the science target acquired in a different orientation of the spacecraft, when available, Choquet et al. 2014), the medium- and narrow-band filter data were reprocessed with PSF libraries of very small sizes (see Table 1). ALICE’s reprocessing for these datasets is not expected to much improve upon classical PSF subtraction techniques.
#
# — [Hagan et al. in prep](https://archive.stsci.edu/missions/hlsp/alice/hlsp_alice_hst_nicmos_all_multi_v1_readme.pdf)

# %%
import glob
from os.path import basename

# %%
header_keywords = ('APERTURE', 'FILTER', 'TARGNAME', 'RA_TARG', 'DEC_TARG', 'PA_V3', 'TARGTYPE', 'TARGCNTR', 'PSFQUAL', 'PSFCRSAT', 'PSFDEGRD')
metadata = {'filename': []}
for kw in header_keywords:
    metadata[kw] = []

# %%
for fn in glob.glob('./data/laplace/dd1/contemp_flats_repaired/*.fits'):
    metadata['filename'].append(fn)
    with open(fn, 'rb') as f:
        hdul = fits.open(f)
        for kw in header_keywords:
            metadata[kw].append(hdul[0].header[kw])

# %%
images = pd.DataFrame(metadata)
images
# Out:
#         APERTURE   DEC_TARG FILTER       PA_V3 PSFCRSAT PSFDEGRD PSFQUAL  \
# 0     NIC2-CORON  28.321111  F110W  245.023605       NO       NO      OK
# 1     NIC2-CORON  28.321111  F160W  245.023605       NO      YES     BAD
# 2     NIC2-CORON  28.321111  F187W  245.023605       NO       NO      OK
# 3     NIC2-CORON  28.321111  F205W  245.023605       NO       NO      OK
# 4     NIC2-CORON  26.180389  F110W  352.049988       NO       NO      OK
# 5     NIC2-CORON  26.180389  F160W  352.049988       NO      YES     BAD
# 6     NIC2-CORON  26.180389  F187W  352.049988       NO       NO      OK
# 7     NIC2-CORON  26.180389  F205W  352.049988       NO       NO      OK
# 8     NIC2-CORON  67.960547  F110W  320.314392       NO       NO      OK
# 9     NIC2-CORON  67.960547  F160W  320.314392       NO      YES     BAD
# 10    NIC2-CORON  67.960547  F187W  320.314392       NO       NO      OK
# 11    NIC2-CORON  67.960547  F205W  320.314392       NO       NO      OK
# 12    NIC2-CORON  51.822222  F160W  331.156097       NO       NO      OK
# 13    NIC2-CORON  51.822222  F160W  331.156097       NO       NO      OK
# 14    NIC2-CORON  51.822222  F160W  331.156097       NO       NO      OK
# 15    NIC2-CORON  51.822222  F160W  331.156097       NO       NO      OK
# 16    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 17    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 18    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 19    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 20    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 21    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 22    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 23    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 24    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 25          NIC2  48.070000  F160W  321.293091       NO       NO      OK
# 26    NIC2-CORON  54.625556  F160W  173.212997       NO       NO      OK
# 27    NIC2-CORON  54.625556  F160W  173.212997       NO       NO      OK
# 28    NIC2-CORON  54.625556  F160W  173.212997       NO       NO      OK
# 29    NIC2-CORON  54.625556  F160W  173.212997       NO       NO      OK
# ...          ...        ...    ...         ...      ...      ...     ...
# 1345  NIC2-CORON  34.201465  F160W  126.857498       NO       NO      OK
# 1346  NIC2-CORON  34.201465  F160W  126.857498       NO       NO      OK
# 1347  NIC2-CORON  34.201465  F160W  126.857498       NO       NO      OK
# 1348  NIC2-CORON  34.201465  F160W  126.857498       NO       NO      OK
# 1349  NIC2-CORON  34.201465  F160W  126.857498       NO       NO      OK
# 1350  NIC2-CORON  34.201465  F160W  126.857498       NO       NO      OK
# 1351  NIC2-CORON  34.201465  F160W  126.857498       NO       NO      OK
# 1352  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1353  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1354  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1355  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1356  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1357  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1358  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1359  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1360  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1361  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1362  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1363  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1364  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1365  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1366  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1367  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1368  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1369  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1370  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1371  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1372  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1373  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
# 1374  NIC2-CORON  34.201465  F160W  126.857597       NO       NO      OK
#
#          RA_TARG    TARGCNTR     TARGNAME         TARGTYPE  \
# 0      64.669500    CENTERED     V892-TAU     POINT_SOURCE
# 1      64.669500    CENTERED     V892-TAU     POINT_SOURCE
# 2      64.669500    CENTERED     V892-TAU      DOUBLE_STAR
# 3      64.669500    CENTERED     V892-TAU      DOUBLE_STAR
# 4      69.619042    CENTERED       DO-TAU     POINT_SOURCE
# 5      69.619042    CENTERED       DO-TAU     POINT_SOURCE
# 6      69.619042    CENTERED       DO-TAU     POINT_SOURCE
# 7      69.619042    CENTERED       DO-TAU     POINT_SOURCE
# 8     311.474542    CENTERED       PV-CEP  EXTENDED_SOURCE
# 9     311.474542    CENTERED       PV-CEP     POINT_SOURCE
# 10    311.474542    CENTERED       PV-CEP  EXTENDED_SOURCE
# 11    311.474542    CENTERED       PV-CEP  EXTENDED_SOURCE
# 12    255.353750    CENTERED   PG1700+518  EXTENDED_SOURCE
# 13    255.353750    CENTERED   PG1700+518  EXTENDED_SOURCE
# 14    255.353750    CENTERED   PG1700+518  EXTENDED_SOURCE
# 15    255.353750    CENTERED   PG1700+518  EXTENDED_SOURCE
# 16    259.909583    CENTERED  PG1718+4807     FAINT_OBJECT
# 17    259.909583    CENTERED  PG1718+4807     FAINT_OBJECT
# 18    259.909583    CENTERED  PG1718+4807     FAINT_OBJECT
# 19    259.909583    CENTERED  PG1718+4807     FAINT_OBJECT
# 20    259.909583    CENTERED  PG1718+4807     FAINT_OBJECT
# 21    259.909583    CENTERED  PG1718+4807     FAINT_OBJECT
# 22    259.909583    CENTERED  PG1718+4807     FAINT_OBJECT
# 23    259.909583    CENTERED  PG1718+4807     FAINT_OBJECT
# 24    259.909583    CENTERED  PG1718+4807     FAINT_OBJECT
# 25    259.909583  UNOCCULTED  PG1718+4807     FAINT_OBJECT
# 26    177.835417    CENTERED  PG1148+5454  EXTENDED_SOURCE
# 27    177.835417    CENTERED  PG1148+5454  EXTENDED_SOURCE
# 28    177.835417    CENTERED  PG1148+5454  EXTENDED_SOURCE
# 29    177.835417    CENTERED  PG1148+5454  EXTENDED_SOURCE
# ...          ...         ...          ...              ...
# 1345  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1346  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1347  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1348  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1349  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1350  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1351  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1352  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1353  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1354  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1355  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1356  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1357  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1358  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1359  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1360  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1361  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1362  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1363  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1364  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1365  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1366  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1367  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1368  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1369  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1370  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1371  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1372  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1373  175.262283  DECENTERED     HD101501     POINT_SOURCE
# 1374  175.262283  DECENTERED     HD101501     POINT_SOURCE
#
#                                                filename
# 0     ./data/laplace/dd1/contemp_flats_repaired/n47f...
# 1     ./data/laplace/dd1/contemp_flats_repaired/n47f...
# 2     ./data/laplace/dd1/contemp_flats_repaired/n47f...
# 3     ./data/laplace/dd1/contemp_flats_repaired/n47f...
# 4     ./data/laplace/dd1/contemp_flats_repaired/n47f...
# 5     ./data/laplace/dd1/contemp_flats_repaired/n47f...
# 6     ./data/laplace/dd1/contemp_flats_repaired/n47f...
# 7     ./data/laplace/dd1/contemp_flats_repaired/n47f...
# 8     ./data/laplace/dd1/contemp_flats_repaired/n47f...
# 9     ./data/laplace/dd1/contemp_flats_repaired/n47f...
# 10    ./data/laplace/dd1/contemp_flats_repaired/n47f...
# 11    ./data/laplace/dd1/contemp_flats_repaired/n47f...
# 12    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 13    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 14    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 15    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 16    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 17    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 18    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 19    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 20    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 21    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 22    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 23    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 24    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 25    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 26    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 27    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 28    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 29    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# ...                                                 ...
# 1345  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1346  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1347  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1348  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1349  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1350  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1351  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1352  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1353  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1354  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1355  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1356  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1357  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1358  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1359  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1360  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1361  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1362  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1363  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1364  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1365  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1366  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1367  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1368  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1369  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1370  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1371  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1372  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1373  ./data/laplace/dd1/contemp_flats_repaired/n534...
# 1374  ./data/laplace/dd1/contemp_flats_repaired/n534...
#
# [1375 rows x 12 columns]

# %%
quality_filter = (
    (images['FILTER'] == 'F160W') &
    (images['PSFQUAL'] == 'OK') &
    (images['PSFCRSAT'] == 'NO') &
    (images['TARGCNTR'] == 'CENTERED') &
    (images['APERTURE'] == 'NIC2-CORON')
)
images[quality_filter]
# Out:
#         APERTURE   DEC_TARG FILTER       PA_V3 PSFCRSAT PSFDEGRD PSFQUAL  \
# 12    NIC2-CORON  51.822222  F160W  331.156097       NO       NO      OK
# 13    NIC2-CORON  51.822222  F160W  331.156097       NO       NO      OK
# 14    NIC2-CORON  51.822222  F160W  331.156097       NO       NO      OK
# 15    NIC2-CORON  51.822222  F160W  331.156097       NO       NO      OK
# 16    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 17    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 18    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 19    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 20    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 21    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 22    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 23    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 24    NIC2-CORON  48.070000  F160W  321.297089       NO       NO      OK
# 26    NIC2-CORON  54.625556  F160W  173.212997       NO       NO      OK
# 27    NIC2-CORON  54.625556  F160W  173.212997       NO       NO      OK
# 28    NIC2-CORON  54.625556  F160W  173.212997       NO       NO      OK
# 29    NIC2-CORON  54.625556  F160W  173.212997       NO       NO      OK
# 30    NIC2-CORON  54.625556  F160W  173.212997       NO       NO      OK
# 33    NIC2-CORON  54.539056  F160W  173.163605       NO       NO      OK
# 34    NIC2-CORON  54.539056  F160W  173.163605       NO       NO      OK
# 35    NIC2-CORON  54.539056  F160W  173.163605       NO       NO      OK
# 36    NIC2-CORON  54.539056  F160W  173.163605       NO       NO      OK
# 67    NIC2-CORON   9.492825  F160W  256.851410       NO       NO      OK
# 68    NIC2-CORON   9.492825  F160W  256.851410       NO       NO      OK
# 69    NIC2-CORON   9.492825  F160W  256.851410       NO       NO      OK
# 70    NIC2-CORON   9.492825  F160W  256.851410       NO       NO      OK
# 71    NIC2-CORON   9.492825  F160W  256.851410       NO       NO      OK
# 84    NIC2-CORON  14.563548  F160W    0.023307       NO       NO      OK
# 85    NIC2-CORON  14.563548  F160W    0.023307       NO       NO      OK
# 86    NIC2-CORON  14.563548  F160W    0.023307       NO       NO      OK
# ...          ...        ...    ...         ...      ...      ...     ...
# 1115  NIC2-CORON -53.034115  F160W   66.682343       NO       NO      OK
# 1116  NIC2-CORON -53.034115  F160W   96.652832       NO       NO      OK
# 1117  NIC2-CORON -53.034115  F160W   96.652832       NO       NO      OK
# 1118  NIC2-CORON -53.034115  F160W   96.652832       NO       NO      OK
# 1187  NIC2-CORON  34.457500  F160W  287.674286       NO       NO      OK
# 1188  NIC2-CORON  34.457500  F160W  287.674286       NO       NO      OK
# 1189  NIC2-CORON  34.457500  F160W  287.674286       NO       NO      OK
# 1190  NIC2-CORON  34.457500  F160W  287.674286       NO       NO      OK
# 1191  NIC2-CORON  34.457500  F160W  287.674286       NO       NO      OK
# 1192  NIC2-CORON  34.457500  F160W  287.674286       NO       NO      OK
# 1193  NIC2-CORON  17.239725  F160W  281.539093       NO       NO      OK
# 1194  NIC2-CORON  17.239725  F160W  281.539093       NO       NO      OK
# 1195  NIC2-CORON  17.239725  F160W  281.539093       NO       NO      OK
# 1196  NIC2-CORON  17.239725  F160W  281.539093       NO       NO      OK
# 1197  NIC2-CORON  17.239725  F160W  281.539093       NO       NO      OK
# 1198  NIC2-CORON  17.239725  F160W  281.539093       NO       NO      OK
# 1199  NIC2-CORON  17.239725  F160W  281.539093       NO       NO      OK
# 1200  NIC2-CORON  17.239725  F160W  281.539093       NO       NO      OK
# 1201  NIC2-CORON  17.239725  F160W  281.539093       NO       NO      OK
# 1202  NIC2-CORON  17.239725  F160W  281.539093       NO       NO      OK
# 1203  NIC2-CORON   2.798645  F160W   70.432663       NO       NO      OK
# 1204  NIC2-CORON   2.798645  F160W   70.432663       NO       NO      OK
# 1205  NIC2-CORON   2.798645  F160W   70.432663       NO       NO      OK
# 1206  NIC2-CORON   2.798645  F160W   70.432663       NO       NO      OK
# 1207  NIC2-CORON   2.798645  F160W   70.432663       NO       NO      OK
# 1208  NIC2-CORON   2.798645  F160W   70.432663       NO       NO      OK
# 1211  NIC2-CORON   9.255263  F160W   76.988922       NO       NO      OK
# 1212  NIC2-CORON   9.255250  F160W   76.988922       NO       NO      OK
# 1217  NIC2-CORON   9.254487  F160W   76.988869       NO       NO      OK
# 1218  NIC2-CORON   9.254476  F160W   76.988869       NO       NO      OK
#
#          RA_TARG  TARGCNTR         TARGNAME         TARGTYPE  \
# 12    255.353750  CENTERED       PG1700+518  EXTENDED_SOURCE
# 13    255.353750  CENTERED       PG1700+518  EXTENDED_SOURCE
# 14    255.353750  CENTERED       PG1700+518  EXTENDED_SOURCE
# 15    255.353750  CENTERED       PG1700+518  EXTENDED_SOURCE
# 16    259.909583  CENTERED      PG1718+4807     FAINT_OBJECT
# 17    259.909583  CENTERED      PG1718+4807     FAINT_OBJECT
# 18    259.909583  CENTERED      PG1718+4807     FAINT_OBJECT
# 19    259.909583  CENTERED      PG1718+4807     FAINT_OBJECT
# 20    259.909583  CENTERED      PG1718+4807     FAINT_OBJECT
# 21    259.909583  CENTERED      PG1718+4807     FAINT_OBJECT
# 22    259.909583  CENTERED      PG1718+4807     FAINT_OBJECT
# 23    259.909583  CENTERED      PG1718+4807     FAINT_OBJECT
# 24    259.909583  CENTERED      PG1718+4807     FAINT_OBJECT
# 26    177.835417  CENTERED      PG1148+5454  EXTENDED_SOURCE
# 27    177.835417  CENTERED      PG1148+5454  EXTENDED_SOURCE
# 28    177.835417  CENTERED      PG1148+5454  EXTENDED_SOURCE
# 29    177.835417  CENTERED      PG1148+5454  EXTENDED_SOURCE
# 30    177.835417  CENTERED      PG1148+5454  EXTENDED_SOURCE
# 33    177.868333  CENTERED  PG1148+5454-PSF     POINT_SOURCE
# 34    177.868333  CENTERED  PG1148+5454-PSF     POINT_SOURCE
# 35    177.868333  CENTERED  PG1148+5454-PSF     POINT_SOURCE
# 36    177.868333  CENTERED  PG1148+5454-PSF     POINT_SOURCE
# 67    100.292021  CENTERED        NGC2264-A  EXTENDED_SOURCE
# 68    100.292021  CENTERED        NGC2264-A  EXTENDED_SOURCE
# 69    100.292021  CENTERED        NGC2264-A  EXTENDED_SOURCE
# 70    100.292021  CENTERED        NGC2264-A  EXTENDED_SOURCE
# 71    100.292021  CENTERED        NGC2264-A  EXTENDED_SOURCE
# 84      3.126191  CENTERED         SAO91772     POINT_SOURCE
# 85      3.126191  CENTERED         SAO91772     POINT_SOURCE
# 86      3.126191  CENTERED         SAO91772     POINT_SOURCE
# ...          ...       ...              ...              ...
# 1115  320.208116  CENTERED         HD202917     POINT_SOURCE
# 1116  320.208116  CENTERED         HD202917     POINT_SOURCE
# 1117  320.208116  CENTERED         HD202917     POINT_SOURCE
# 1118  320.208116  CENTERED         HD202917     POINT_SOURCE
# 1187  191.843792  CENTERED     QSO1244+3443         FAINTOBJ
# 1188  191.843792  CENTERED     QSO1244+3443         FAINTOBJ
# 1189  191.843792  CENTERED     QSO1244+3443         FAINTOBJ
# 1190  191.843792  CENTERED     QSO1244+3443         FAINTOBJ
# 1191  191.843792  CENTERED     QSO1244+3443         FAINTOBJ
# 1192  191.843792  CENTERED     QSO1244+3443         FAINTOBJ
# 1193  183.262800  CENTERED    LBQS1210+1731         FAINTOBJ
# 1194  183.262800  CENTERED    LBQS1210+1731         FAINTOBJ
# 1195  183.262800  CENTERED    LBQS1210+1731         FAINTOBJ
# 1196  183.262800  CENTERED    LBQS1210+1731         FAINTOBJ
# 1197  183.262800  CENTERED    LBQS1210+1731         FAINTOBJ
# 1198  183.262800  CENTERED    LBQS1210+1731         FAINTOBJ
# 1199  183.262800  CENTERED    LBQS1210+1731         FAINTOBJ
# 1200  183.262800  CENTERED    LBQS1210+1731         FAINTOBJ
# 1201  183.262800  CENTERED    LBQS1210+1731         FAINTOBJ
# 1202  183.262800  CENTERED    LBQS1210+1731         FAINTOBJ
# 1203  338.146946  CENTERED    LBQS2230+0232         FAINTOBJ
# 1204  338.146946  CENTERED    LBQS2230+0232         FAINTOBJ
# 1205  338.146946  CENTERED    LBQS2230+0232         FAINTOBJ
# 1206  338.146946  CENTERED    LBQS2230+0232         FAINTOBJ
# 1207  338.146946  CENTERED    LBQS2230+0232         FAINTOBJ
# 1208  338.146946  CENTERED    LBQS2230+0232         FAINTOBJ
# 1211   29.919928  CENTERED        ENCELADUS     POINT_SOURCE
# 1212   29.919881  CENTERED        ENCELADUS     POINT_SOURCE
# 1217   29.916580  CENTERED        ENCELADUS     POINT_SOURCE
# 1218   29.916522  CENTERED        ENCELADUS     POINT_SOURCE
#
#                                                filename
# 12    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 13    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 14    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 15    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 16    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 17    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 18    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 19    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 20    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 21    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 22    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 23    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 24    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 26    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 27    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 28    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 29    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 30    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 33    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 34    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 35    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 36    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 67    ./data/laplace/dd1/contemp_flats_repaired/n4lz...
# 68    ./data/laplace/dd1/contemp_flats_repaired/n4lz...
# 69    ./data/laplace/dd1/contemp_flats_repaired/n4lz...
# 70    ./data/laplace/dd1/contemp_flats_repaired/n4lz...
# 71    ./data/laplace/dd1/contemp_flats_repaired/n4lz...
# 84    ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 85    ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 86    ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# ...                                                 ...
# 1115  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1116  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1117  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1118  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1187  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1188  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1189  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1190  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1191  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1192  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1193  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1194  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1195  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1196  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1197  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1198  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1199  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1200  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1201  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1202  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1203  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1204  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1205  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1206  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1207  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1208  ./data/laplace/dd1/contemp_flats_repaired/n4ta...
# 1211  ./data/laplace/dd1/contemp_flats_repaired/n4uw...
# 1212  ./data/laplace/dd1/contemp_flats_repaired/n4uw...
# 1217  ./data/laplace/dd1/contemp_flats_repaired/n4uw...
# 1218  ./data/laplace/dd1/contemp_flats_repaired/n4uw...
#
# [702 rows x 12 columns]

# %%
psf_references_filter = (
    (images['FILTER'] == 'F160W') &
    (images['PSFQUAL'] == 'OK') &
    (images['PSFCRSAT'] == 'NO') &
    (images['TARGCNTR'] == 'CENTERED') &
    (images['TARGTYPE'] == 'POINT_SOURCE') &
    (images['APERTURE'] == 'NIC2-CORON')
)
images[psf_references_filter]
# Out:
#         APERTURE   DEC_TARG FILTER       PA_V3 PSFCRSAT PSFDEGRD PSFQUAL  \
# 33    NIC2-CORON  54.539056  F160W  173.163605       NO       NO      OK
# 34    NIC2-CORON  54.539056  F160W  173.163605       NO       NO      OK
# 35    NIC2-CORON  54.539056  F160W  173.163605       NO       NO      OK
# 36    NIC2-CORON  54.539056  F160W  173.163605       NO       NO      OK
# 84    NIC2-CORON  14.563548  F160W    0.023307       NO       NO      OK
# 85    NIC2-CORON  14.563548  F160W    0.023307       NO       NO      OK
# 86    NIC2-CORON  14.563548  F160W    0.023307       NO       NO      OK
# 87    NIC2-CORON  14.563548  F160W    0.023307       NO       NO      OK
# 106   NIC2-CORON  14.563550  F160W   44.999901       NO       NO      OK
# 107   NIC2-CORON  14.563550  F160W   44.999901       NO       NO      OK
# 108   NIC2-CORON  14.563550  F160W   44.999901       NO       NO      OK
# 109   NIC2-CORON  14.563550  F160W   44.999901       NO       NO      OK
# 172   NIC2-CORON   1.783568  F160W  270.002808       NO       NO      OK
# 173   NIC2-CORON   1.783568  F160W  270.002808       NO       NO      OK
# 174   NIC2-CORON   1.783568  F160W  270.002808       NO       NO      OK
# 175   NIC2-CORON   1.783568  F160W  270.002808       NO       NO      OK
# 194   NIC2-CORON   1.783555  F160W  103.996597       NO       NO      OK
# 195   NIC2-CORON   1.783555  F160W  103.996597       NO       NO      OK
# 196   NIC2-CORON   1.783555  F160W  103.996597       NO       NO      OK
# 197   NIC2-CORON   1.783555  F160W  103.996597       NO       NO      OK
# 216   NIC2-CORON -16.520833  F160W  292.964813       NO       NO      OK
# 217   NIC2-CORON -16.520833  F160W  292.964813       NO       NO      OK
# 218   NIC2-CORON -16.520833  F160W  292.964813       NO       NO      OK
# 219   NIC2-CORON -16.520833  F160W  292.964813       NO       NO      OK
# 238   NIC2-CORON -16.520831  F160W  139.037704       NO       NO      OK
# 239   NIC2-CORON -16.520831  F160W  139.037704       NO       NO      OK
# 240   NIC2-CORON -16.520831  F160W  139.037704       NO       NO      OK
# 241   NIC2-CORON -16.520831  F160W  139.037704       NO       NO      OK
# 282   NIC2-CORON -65.448633  F160W  118.518303       NO       NO      OK
# 283   NIC2-CORON -65.448633  F160W  118.518303       NO       NO      OK
# ...          ...        ...    ...         ...      ...      ...     ...
# 1093  NIC2-CORON -31.565531  F160W  149.727905       NO       NO      OK
# 1094  NIC2-CORON -31.565531  F160W  149.727905       NO       NO      OK
# 1095  NIC2-CORON -31.565531  F160W  149.727905       NO       NO      OK
# 1096  NIC2-CORON -31.565531  F160W  149.727905       NO       NO      OK
# 1097  NIC2-CORON -31.565531  F160W  149.727905       NO       NO      OK
# 1098  NIC2-CORON -31.565531  F160W  149.727905       NO       NO      OK
# 1099  NIC2-CORON -31.565531  F160W  149.727905       NO       NO      OK
# 1100  NIC2-CORON -31.565531  F160W  149.727905       NO       NO      OK
# 1101  NIC2-CORON -31.565531  F160W  149.727905       NO       NO      OK
# 1102  NIC2-CORON -31.565531  F160W  149.727905       NO       NO      OK
# 1103  NIC2-CORON -31.565531  F160W  149.727905       NO       NO      OK
# 1104  NIC2-CORON -31.565531  F160W  149.727905       NO       NO      OK
# 1105  NIC2-CORON -31.565531  F160W  149.727905       NO       NO      OK
# 1106  NIC2-CORON -31.565531  F160W  149.727905       NO       NO      OK
# 1107  NIC2-CORON  79.003433  F160W  306.910004       NO       NO      OK
# 1108  NIC2-CORON  79.003433  F160W  306.910004       NO       NO      OK
# 1109  NIC2-CORON  79.003433  F160W  306.910004       NO       NO      OK
# 1110  NIC2-CORON  79.003433  F160W  336.769501       NO       NO      OK
# 1111  NIC2-CORON  79.003433  F160W  336.769501       NO       NO      OK
# 1112  NIC2-CORON  79.003433  F160W  336.769501       NO       NO      OK
# 1113  NIC2-CORON -53.034115  F160W   66.682343       NO       NO      OK
# 1114  NIC2-CORON -53.034115  F160W   66.682343       NO       NO      OK
# 1115  NIC2-CORON -53.034115  F160W   66.682343       NO       NO      OK
# 1116  NIC2-CORON -53.034115  F160W   96.652832       NO       NO      OK
# 1117  NIC2-CORON -53.034115  F160W   96.652832       NO       NO      OK
# 1118  NIC2-CORON -53.034115  F160W   96.652832       NO       NO      OK
# 1211  NIC2-CORON   9.255263  F160W   76.988922       NO       NO      OK
# 1212  NIC2-CORON   9.255250  F160W   76.988922       NO       NO      OK
# 1217  NIC2-CORON   9.254487  F160W   76.988869       NO       NO      OK
# 1218  NIC2-CORON   9.254476  F160W   76.988869       NO       NO      OK
#
#          RA_TARG  TARGCNTR         TARGNAME      TARGTYPE  \
# 33    177.868333  CENTERED  PG1148+5454-PSF  POINT_SOURCE
# 34    177.868333  CENTERED  PG1148+5454-PSF  POINT_SOURCE
# 35    177.868333  CENTERED  PG1148+5454-PSF  POINT_SOURCE
# 36    177.868333  CENTERED  PG1148+5454-PSF  POINT_SOURCE
# 84      3.126191  CENTERED         SAO91772  POINT_SOURCE
# 85      3.126191  CENTERED         SAO91772  POINT_SOURCE
# 86      3.126191  CENTERED         SAO91772  POINT_SOURCE
# 87      3.126191  CENTERED         SAO91772  POINT_SOURCE
# 106     3.126187  CENTERED         SAO91772  POINT_SOURCE
# 107     3.126187  CENTERED         SAO91772  POINT_SOURCE
# 108     3.126187  CENTERED         SAO91772  POINT_SOURCE
# 109     3.126187  CENTERED         SAO91772  POINT_SOURCE
# 172    74.895103  CENTERED            GJ182  POINT_SOURCE
# 173    74.895103  CENTERED            GJ182  POINT_SOURCE
# 174    74.895103  CENTERED            GJ182  POINT_SOURCE
# 175    74.895103  CENTERED            GJ182  POINT_SOURCE
# 194    74.895129  CENTERED            GJ182  POINT_SOURCE
# 195    74.895129  CENTERED            GJ182  POINT_SOURCE
# 196    74.895129  CENTERED            GJ182  POINT_SOURCE
# 197    74.895129  CENTERED            GJ182  POINT_SOURCE
# 216   187.462221  CENTERED        HD108767B  POINT_SOURCE
# 217   187.462221  CENTERED        HD108767B  POINT_SOURCE
# 218   187.462221  CENTERED        HD108767B  POINT_SOURCE
# 219   187.462221  CENTERED        HD108767B  POINT_SOURCE
# 238   187.462238  CENTERED        HD108767B  POINT_SOURCE
# 239   187.462238  CENTERED        HD108767B  POINT_SOURCE
# 240   187.462238  CENTERED        HD108767B  POINT_SOURCE
# 241   187.462238  CENTERED        HD108767B  POINT_SOURCE
# 282    82.186467  CENTERED      HD36705-NEW  POINT_SOURCE
# 283    82.186467  CENTERED      HD36705-NEW  POINT_SOURCE
# ...          ...       ...              ...           ...
# 1093  344.100197  CENTERED            GL879  POINT_SOURCE
# 1094  344.100197  CENTERED            GL879  POINT_SOURCE
# 1095  344.100197  CENTERED            GL879  POINT_SOURCE
# 1096  344.100197  CENTERED            GL879  POINT_SOURCE
# 1097  344.100197  CENTERED            GL879  POINT_SOURCE
# 1098  344.100197  CENTERED            GL879  POINT_SOURCE
# 1099  344.100197  CENTERED            GL879  POINT_SOURCE
# 1100  344.100197  CENTERED            GL879  POINT_SOURCE
# 1101  344.100197  CENTERED            GL879  POINT_SOURCE
# 1102  344.100197  CENTERED            GL879  POINT_SOURCE
# 1103  344.100197  CENTERED            GL879  POINT_SOURCE
# 1104  344.100197  CENTERED            GL879  POINT_SOURCE
# 1105  344.100197  CENTERED            GL879  POINT_SOURCE
# 1106  344.100197  CENTERED            GL879  POINT_SOURCE
# 1107  349.860271  CENTERED         HD220140  POINT_SOURCE
# 1108  349.860271  CENTERED         HD220140  POINT_SOURCE
# 1109  349.860271  CENTERED         HD220140  POINT_SOURCE
# 1110  349.860271  CENTERED         HD220140  POINT_SOURCE
# 1111  349.860271  CENTERED         HD220140  POINT_SOURCE
# 1112  349.860271  CENTERED         HD220140  POINT_SOURCE
# 1113  320.208116  CENTERED         HD202917  POINT_SOURCE
# 1114  320.208116  CENTERED         HD202917  POINT_SOURCE
# 1115  320.208116  CENTERED         HD202917  POINT_SOURCE
# 1116  320.208116  CENTERED         HD202917  POINT_SOURCE
# 1117  320.208116  CENTERED         HD202917  POINT_SOURCE
# 1118  320.208116  CENTERED         HD202917  POINT_SOURCE
# 1211   29.919928  CENTERED        ENCELADUS  POINT_SOURCE
# 1212   29.919881  CENTERED        ENCELADUS  POINT_SOURCE
# 1217   29.916580  CENTERED        ENCELADUS  POINT_SOURCE
# 1218   29.916522  CENTERED        ENCELADUS  POINT_SOURCE
#
#                                                filename
# 33    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 34    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 35    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 36    ./data/laplace/dd1/contemp_flats_repaired/n4fh...
# 84    ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 85    ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 86    ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 87    ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 106   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 107   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 108   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 109   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 172   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 173   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 174   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 175   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 194   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 195   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 196   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 197   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 216   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 217   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 218   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 219   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 238   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 239   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 240   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 241   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 282   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# 283   ./data/laplace/dd1/contemp_flats_repaired/n4n4...
# ...                                                 ...
# 1093  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1094  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1095  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1096  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1097  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1098  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1099  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1100  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1101  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1102  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1103  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1104  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1105  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1106  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1107  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1108  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1109  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1110  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1111  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1112  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1113  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1114  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1115  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1116  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1117  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1118  ./data/laplace/dd1/contemp_flats_repaired/n4qs...
# 1211  ./data/laplace/dd1/contemp_flats_repaired/n4uw...
# 1212  ./data/laplace/dd1/contemp_flats_repaired/n4uw...
# 1217  ./data/laplace/dd1/contemp_flats_repaired/n4uw...
# 1218  ./data/laplace/dd1/contemp_flats_repaired/n4uw...
#
# [558 rows x 12 columns]

# %%
import photutils

# %%
from astropy.nddata.utils import Cutout2D

# %%
BOX_SIZE = 80 # pixels

# %%
images.to_records().dtype
# Out:
# dtype((numpy.record, [('index', '<i8'), ('APERTURE', 'O'), ('DEC_TARG', '<f8'), ('FILTER', 'O'), ('PA_V3', '<f8'), ('PSFCRSAT', 'O'), ('PSFDEGRD', 'O'), ('PSFQUAL', 'O'), ('RA_TARG', '<f8'), ('TARGCNTR', 'O'), ('TARGNAME', 'O'), ('TARGTYPE', 'O'), ('filename', 'O')]))

# %%
def cutouts_cube_fits(dataframe):
    cutout_psfs = []
    for row in dataframe.itertuples():
        with open(row.filename, 'rb') as f:
            hdul = fits.open(f, memmap=False)
            x, y = hdul[0].header['TARSIAFX'], hdul[0].header['TARSIAFY']
            cutout = Cutout2D(hdul['SCI'].data, (x, y), BOX_SIZE)
            cutout_psfs.append(cutout.data)
    cutout_psfs_cube = np.asarray(cutout_psfs)
    images_recarray = dataframe.to_records()
    # Force strings to be strings, not objects
    images_recarray = images_recarray.astype(np.dtype((numpy.record, [('index', '<i8'), ('APERTURE', 'U20'), ('DEC_TARG', '<f8'), ('FILTER', 'U20'), ('PA_V3', '<f8'), ('PSFCRSAT', 'U20'), ('PSFDEGRD', 'U20'), ('PSFQUAL', 'U20'), ('RA_TARG', '<f8'), ('TARGCNTR', 'U20'), ('TARGNAME', 'U20'), ('TARGTYPE', 'U20'), ('filename', 'U80')])))
    table_hdu = fits.TableHDU(data=images_recarray)
    cube_hdul = fits.HDUList(
        [
            fits.PrimaryHDU(),
            fits.ImageHDU(cutout_psfs_cube),
            table_hdu
        ]
    )
    return cube_hdul

# %%
psf_ref_hdul = cutouts_cube_fits(images[psf_references_filter])
psf_ref_hdul.writeto('./data/laplace/nicmos_f160w_psf_ref.fits', overwrite=True)
# Out:
# I21
# A20
# D25.17
# A20
# D25.17
# A20
# A20
# A20
# D25.17
# A20
# A20
# A20
# A80

# %%
data_hdul = cutouts_cube_fits(images[quality_filter])
data_hdul.writeto('./data/laplace/nicmos_f160w_data.fits', overwrite=True)
# Out:
# I21
# A20
# D25.17
# A20
# D25.17
# A20
# A20
# A20
# D25.17
# A20
# A20
# A20
# A80

# %%
# !du -hs ./data/laplace/nicmos_*.fits
# Out:
#  35M	./data/laplace/nicmos_f160w_data.fits
#  27M	./data/laplace/nicmos_f160w_psf_ref.fits
